# %%
#from backtesting-J import *
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original = pd.read_csv("cases.csv")

# %%
ori = original[35:549]
ori.head(1)
# Out:
#           Date  New cases  Cumulative cases  Cumulative Vancouver Coastal  \
# 35  2020-04-01       53.0            1066.0                         497.0
#
#     Cumulative Fraser Health  Cumulative Island Health   \
# 35                     367.0                       72.0
#
#     Cumulative Interior Health  Cumulative Northern Health  \
# 35                       114.0                        16.0
#
#     Hospitalization (Currently in hospital)  ICU (Currently in ICU)  \
# 35                                    142.0                    67.0
#
#     Recovered  Deaths  Cumulative deaths  Active cases
# 35      606.0     1.0               25.0         435.0

# %%
ori = ori.reset_index(drop=True)
ori.head(1)
# Out:
#          Date  New cases  Cumulative cases  Cumulative Vancouver Coastal  \
# 0  2020-04-01       53.0            1066.0                         497.0
#
#    Cumulative Fraser Health  Cumulative Island Health   \
# 0                     367.0                       72.0
#
#    Cumulative Interior Health  Cumulative Northern Health  \
# 0                       114.0                        16.0
#
#    Hospitalization (Currently in hospital)  ICU (Currently in ICU)  Recovered  \
# 0                                    142.0                    67.0      606.0
#
#    Deaths  Cumulative deaths  Active cases
# 0     1.0               25.0         435.0

# %%
prediction = pd.read_csv("predictions.csv")

# %%
pre1 = prediction[:514]
pre1.head(1)
# Out:
#      Date:Delay      Count
# 0  2020-04-01:1  43.203682

# %%
fig, ax = plt.subplots()
sns.set(rc = {'figure.figsize':(14,8.27)})
sns.lineplot(data = ori['New cases'], ax = ax, color = 'b')#, label='merged')
sns.lineplot(data = pre1['Count'], ax = ax, color = 'r')#, label='predicted')
plt.title('Daily New COVID-19 Cases - Merged Data (Original + Water Waste)', fontsize = 20) # title with fontsize 20
plt.legend(labels = ["Merged", "Predicted"], fontsize = 16)
plt.xlabel("Time (days)", fontsize = 16)
plt.ylabel("New Cases", fontsize = 16)
# Out:
# Text(0, 0.5, 'New Cases')
